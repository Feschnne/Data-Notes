# %% [markdown]
# # Plantilla de Nota Técnica
#
# ## 1. Título
# Escribe aquí el título (ej. "SQL - Window Functions")
#
# ## 2. Objetivo
# Explica en una grase clara qué vas a aprender,
#
# ## 3. Explicación teórica breve
# Describe con tus palabras qué es este concepto, para qué sirve y cuándo se usa.
#
# ## 4. Ejemplos ejecutables
# Aquí van celdas con código:
# - Python
# - SQL
# - PySpark
# - etc...
#
# ## 5. Errores comunes
# - Error 1
# - Error 2
# - Error 3
#
# ## 6. Ejercicio práctico
# Enuncia aquí un pequeño reto que puedas resolver luego.
#
# ## 7. Recursos
# - Enlace 1
# - Enlace 2
